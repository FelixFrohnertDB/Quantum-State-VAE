# %% [markdown]
# Import Libraries:

# %%
# %matplotlib inline
# %matplotlib notebook
from sklearn.model_selection import train_test_split
import numpy as np
import qutip as qt
from qiskit.quantum_info import Statevector, DensityMatrix, entropy, partial_trace
from qiskit import QuantumRegister, ClassicalRegister
from qiskit import QuantumCircuit, execute
from vae import *

# %%
fig_size_dim    = 4
golden_ratio    = (1+np.sqrt(5))/2
fig_size        = (fig_size_dim, fig_size_dim/golden_ratio)

def plot_style():
    font_size       = 12
    dpi             = 200

    params = {'figure.figsize': fig_size,
              'figure.dpi': dpi,
              'savefig.dpi': dpi,
              'font.size': font_size,
              'font.family': "sans-serif",
              'font.sans-serif': ["Helvetica"],
              'figure.titlesize': font_size,
              'legend.fontsize': font_size,
              'axes.labelsize': font_size,
              'axes.titlesize': font_size,
              'xtick.labelsize': font_size,
              'ytick.labelsize': font_size,
              'text.usetex': True,
             }

    plt.rcParams.update(params)
plot_style()

# %%
def circuit(theta):
    q = QuantumRegister(2,'q')
    circuit = QuantumCircuit(q)
    circuit.h(q[0])
    circuit.cry(theta,q[0],q[1])
    return circuit

def get_dm(theta):
    state = Statevector.from_int(0, 2**2)
    state = state.evolve(circuit(theta))
    return DensityMatrix(state)


def get_u(n):
    z = np.random.randn(n,n)/np.sqrt(2.0)
    q,r = np.linalg.qr(z)
    d = np.diagonal(r)
    ph = d/np.absolute(d)
    q = np.multiply(q,ph,q)
    return q

def apply_u(dm):
    UaUb = qt.Qobj(np.kron(get_u(2),get_u(2)),dims = [[2, 2], [2, 2]])
    return  UaUb * dm * UaUb.dag()  

def gen_angle_circ(n_points, n_samples, max_epsilon):
    th_scan_template = np.linspace(0, np.pi, n_points)
    th_scan = np.zeros((n_points, n_samples))
    for cnt, theta in enumerate(th_scan_template):
        th_scan[cnt] = theta + max_epsilon * np.random.uniform(-1, 1, size=n_samples)
    return th_scan

def apply_deco(alpha, dm):
#     return alpha*dm  + (1 - alpha)/2**2 * dm.tr() * qt.identity([2,2])
    return (1 - alpha)*dm  + alpha/2**2 * qt.identity([2,2])

# %%
dm = get_dm(np.pi)

r_1 = apply_deco(0,apply_u( qt.Qobj(dm.data,dims=[[2,2],[2,2]])))

r_2 = apply_deco(0.1,apply_u( qt.Qobj(dm.data,dims=[[2,2],[2,2]])))

# %%
# Out:
# Quantum object: dims = [[4], [4]], shape = (4, 4), type = oper, isherm = True
# Qobj data =
# [[ 0.30213025+0.j         -0.13325465-0.0264831j  -0.00563055-0.00072139j
#   -0.10854862-0.33298242j]
#  [-0.13325465+0.0264831j   0.16990036+0.j          0.04800158-0.0309558j
#    0.09476356+0.17455167j]
#  [-0.00563055+0.00072139j  0.04800158+0.0309558j   0.05059952+0.j
#   -0.00652858+0.06152548j]
#  [-0.10854862+0.33298242j  0.09476356-0.17455167j -0.00652858-0.06152548j
#    0.47736987+0.j        ]]

# %%
n_points = 101#101#51#41#21
n_samples = 10
scan_arr = np.linspace(0,np.pi,n_points)


rho_arr_noisy = np.zeros((n_points,n_samples,4,4))

for i, theta in enumerate(th_scan):   
        
    dm = get_dm(theta) 
    
    for inx, s in enumerate(range(n_samples)):
        rho_arr_noisy[i,inx] = apply_u( qt.Qobj(dm.data,dims=[[2,2],[2,2]]))
            
rho_arr_noisy = np.reshape(rho_arr_noisy,(n_points*n_samples,16))
# Out:
# /tmp/ipykernel_139240/4088805558.py:13: ComplexWarning: Casting complex values to real discards the imaginary part
#   rho_arr_noisy[i,inx] = apply_u( qt.Qobj(dm.data,dims=[[2,2],[2,2]]))

# %%
alpha_arr = np.zeros(len(rho_arr_noisy))
cnt = 0
for theta in scan_arr:
        for _ in (range(n_samples)):
            alpha_arr[cnt] = theta
            cnt += 1


X_train, X_test, y_train, y_test = train_test_split(rho_arr_noisy, alpha_arr, random_state=42)
concurrence_arr = np.array([qt.concurrence(qt.Qobj(dm.reshape(4,4),dims=[[2,2],[2,2]])) for dm in X_test])

# %% [markdown]
# Define Hyperparameters:

# %%
batch_size = 64
beta = 0.75
learning_rate = 0.005
lat_dim = 1
hidden_act = "tanh"
final_act = "linear"

# %% [markdown]
# Load trained VAE:

# %%
encoder, decoder = vae_mlp_4x4(lat_dim, hidden_act, final_act)

vae_noisy = VAE(encoder, decoder, beta)
vae_noisy.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
vae_noisy.fit(X_test, epochs=10, batch_size=64, verbose=1) 

z_mean, z_log_var, z = vae_noisy.encoder.predict(X_test)
# Out:
# Epoch 1/10
# 2023-03-28 12:26:08.123169: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-28 12:26:08.123198: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-28 12:26:08.123222: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (felix-Latitude-5521): /proc/driver/nvidia/version does not exist
# 2023-03-28 12:26:08.123507: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 4/4 [==============================] - 1s 3ms/step - loss: 5.1873 - reconstruction_loss: 4.8869 - kl_loss: 0.0490
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7367 - reconstruction_loss: 3.5968 - kl_loss: 0.0338
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 3.3417 - reconstruction_loss: 3.2380 - kl_loss: 0.0522
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 3.1572 - reconstruction_loss: 3.0797 - kl_loss: 0.0659
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0981 - reconstruction_loss: 3.0097 - kl_loss: 0.0668
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0521 - reconstruction_loss: 2.9903 - kl_loss: 0.0561
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0166 - reconstruction_loss: 2.9674 - kl_loss: 0.0483
# Epoch 8/10
# 4/4 [==============================] - 0s 1ms/step - loss: 3.0233 - reconstruction_loss: 2.9809 - kl_loss: 0.0437
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0130 - reconstruction_loss: 2.9694 - kl_loss: 0.0356
# Epoch 10/10
# 4/4 [==============================] - 0s 1ms/step - loss: 3.0252 - reconstruction_loss: 2.9737 - kl_loss: 0.0280
# 8/8 [==============================] - 0s 1ms/step

# %% [markdown]
# Investigate Latent Space

# %%
plot_scatter(y_test,z_mean[:,0],concurrence_arr,"Angle $\\theta$","Latent Parameter $Z_0$","Concurrence",1)

# %%
n = 2 

z = np.random.randn(n,n)/np.sqrt(2.0)
q,r = np.linalg.qr(z)
d = np.diagonal(r)
ph = d/np.absolute(d)
q = np.multiply(q,ph,q)

q
# Out:
# array([[-0.66264884, -0.74893025],
#        [-0.74893025,  0.66264884]])

# %%
z = np.random.randn(n,n)/np.sqrt(2.0)
q,r = np.linalg.qr(z)
d = np.diagonal(r)
ph = d/np.absolute(d)
q2 = np.multiply(q,ph,q)
q2
# Out:
# array([[ 0.40231175,  0.91550273],
#        [-0.91550273,  0.40231175]])

# %%
t = np.kron(q,q2)

np.dot(t, np.transpose(t))
# Out:
# array([[ 1.00000000e+00, -6.80185066e-18, -6.80185066e-18,
#         -2.12997526e-17],
#        [-6.80185066e-18,  1.00000000e+00, -2.42380643e-18,
#          1.00858211e-17],
#        [-6.80185066e-18, -2.42380643e-18,  1.00000000e+00,
#         -1.76697545e-17],
#        [-2.12997526e-17,  1.00858211e-17, -1.76697545e-17,
#          1.00000000e+00]])
